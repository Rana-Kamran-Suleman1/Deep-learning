# %%
import numpy as np
import tensorflow as tf
import keras
from keras.models import Sequential 
from keras.layers import Input, Dense

# %%
# With Numpy
xs=np.array([-1,0,1,2,3,4],dtype=np.float32)
ys=np.array([-3,1,1,3,5,7],dtype=np.float32)
# With Tensorflow
# x_tf=tf.constant([-1,0,1,2,3,4],dtype=tf.float64)
# y_tf=tf.constant([-3,-1,1,3,5,7],dtype=tf.float64)

# %%
# model=Sequential([
#     Input(shape=[1]),
#     Dense(units=1)
# ])

############# method 2 With Keras

model=keras.Sequential([
    keras.Input(shape=[1]),
    keras.layers.Dense(units=1)
])
################ method 3 With Keras
# model=keras.Sequential()
# model.add(keras.Input(shape=(1,)))
# model.add(keras.layers.Dense(units=1))

#1. Sequential API
#2. Functional API 
#3. Subclass API (For Own Customize)

# %%
# model.compile(loss="mean_squared_error")

model.compile(
    optimizer=keras.optimizers.SGD(learning_rate=0.1) , #learning Rate will be slow then learning time will be fast #Inverse
    loss=keras.losses.MeanSquaredError(),
    matrics=[keeas]
    )

# %%
# With Numpy
model.fit(xs,ys,epochs=300)

# With Tensorflow
# model.fit(x_tf,y_tf,epochs=300)
# Out:
# Epoch 1/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 532ms/step - loss: 13.8475
# Epoch 2/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - loss: 1.0391
# Epoch 3/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - loss: 0.7551
# Epoch 4/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - loss: 0.6964
# Epoch 5/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - loss: 0.6520
# Epoch 6/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step - loss: 0.6163
# Epoch 7/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step - loss: 0.5876
# Epoch 8/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step - loss: 0.5646
# Epoch 9/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step - loss: 0.5460
# Epoch 10/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step - loss: 0.5311
# Epoch 11/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step - loss: 0.5191
# Epoch 12/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step - loss: 0.5095
# Epoch 13/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step - loss: 0.5017
# Epoch 14/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - loss: 0.4955
# ...

# %%
model.predict(tf.constant([[10]]))
# Out:
# WARNING:tensorflow:5 out of the last 5 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x000002A4EE7EFCE0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# array([[17.87619]], dtype=float32)
